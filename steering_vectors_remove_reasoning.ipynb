# %%
import numpy as np
from datasets import load_dataset
import numpy as np
import torch.nn.functional as F
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
def get_orthogonalized_matrix(W, direction):
    """
    Orthogonalize weight matrix W w.r.t. a direction vector.
    W: torch.Tensor of shape [out_dim, in_dim]
    direction: torch.Tensor of shape [out_dim]
    """
    direction = direction / direction.norm()  # normalize to a unit vector
    projection = torch.ger(direction, direction)  # take outer product
    return W - torch.mm(projection, W)  # subtract project part

# %%
# MODEL_NAME = "Qwen/QwQ-32B-Preview"
MODEL_NAME = "deepseek-ai/DeepSeek-R1-Distill-Llama-8B"

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    device_map="cuda:3",
    quantization_config=BitsAndBytesConfig(
        load_in_8bit=True,
    ),
)
model.eval()

steering_vectors = torch.load("steering_vectors_Wait.pt")


# Sort by absolute mean of the steering vectors
activation_scored = sorted(
    [
        (layer_idx, vec / vec.norm()) for layer_idx, vec in steering_vectors.items()
        if isinstance(vec, torch.Tensor)
    ],
    key=lambda x: abs(x[1].float().mean().item()),  # Convert to float32 for better precision
    reverse=True,
)

# Display top-k layers with strongest steering signal
top_k = 50
# print("Top-k layers by abs mean activation:")
for i, (layer_id, vec) in enumerate(activation_scored[:top_k]):
    print(f"#{i}: Layer {layer_id:<2}      | Mean = {abs(vec.float().mean()):.4f}      | Norm = {vec.float().norm():.2f}")


# Apply to all layers
layer_idx = 10

for i, layer in enumerate(model.model.layers):
    device = layer.self_attn.o_proj.weight.device
    print(device)
    steering_vector = steering_vectors[layer_idx].to(device)

    # Convert to float16 before modification
    W_o_proj = layer.self_attn.o_proj.weight.data.to(device = device, dtype=torch.float16)
    W_down_proj = layer.mlp.down_proj.weight.data.to(device = device, dtype=torch.float16)
    
    # Apply orthogonalization
    W_o_proj_orth = get_orthogonalized_matrix(W_o_proj, steering_vector)
    W_down_proj_orth = get_orthogonalized_matrix(W_down_proj, steering_vector)


    # Restore original dtype
    layer.self_attn.o_proj.weight.data = W_o_proj_orth.to(layer.self_attn.o_proj.weight.dtype)
    layer.mlp.down_proj.weight.data = W_down_proj_orth.to(layer.mlp.down_proj.weight.dtype)

    print(f"Orthogonalized layer {i} using layer {steering_vector}'s vector")

model.save_pretrained("my_models/DeepSeek-R1-Distill-Llama-8B-orthogonalized-10")
tokenizer.save_pretrained("my_models/DeepSeek-R1-Distill-Llama-8B-orthogonalized-10")

from huggingface_hub import login
login()

model.push_to_hub("dipikakhullar/DeepSeek-R1-Distill-Llama-8B-orthogonalized-10")
tokenizer.push_to_hub("dipikakhullar/DeepSeek-R1-Distill-Llama-8B-orthogonalized-10")

# %%
steering_vectors = torch.load("steering_vectors_Wait.pt")

layer_idx = 10
layer = model.model.layers[layer_idx]

device = layer.self_attn.o_proj.weight.device
steering_vector = steering_vectors[layer_idx].to(device)


print(model.model.layers[layer_idx])  # to double check module names
model.model.layers[layer_idx].self_attn.o_proj.weight.data  # Might not even exist or be what you expect

# Convert to float16 before modification
W_o_proj = layer.self_attn.o_proj.weight.data.to(device = device, dtype=torch.float16)
W_down_proj = layer.mlp.down_proj.weight.data.to(device = device, dtype=torch.float16)

# Apply orthogonalization
W_o_proj_orth = get_orthogonalized_matrix(W_o_proj, steering_vector)
W_down_proj_orth = get_orthogonalized_matrix(W_down_proj, steering_vector)

# Convert back to original dtype before reassigning
layer.self_attn.o_proj.weight.data = W_o_proj_orth.to(layer.self_attn.o_proj.weight.dtype)
layer.mlp.down_proj.weight.data = W_down_proj_orth.to(layer.mlp.down_proj.weight.dtype)

print("Layer self_attn.o_proj weight device:", layer.self_attn.o_proj.weight.device)
print("Layer mlp.down_proj weight device:", layer.mlp.down_proj.weight.device)
print("Steering vector device:", steering_vector.device)
# Out:
# /tmp/ipykernel_314190/2638095593.py:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   steering_vectors = torch.load("steering_vectors_Wait.pt")
# LlamaDecoderLayer(
#   (self_attn): LlamaAttention(
#     (q_proj): Linear8bitLt(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear8bitLt(in_features=4096, out_features=1024, bias=False)
#     (v_proj): Linear8bitLt(in_features=4096, out_features=1024, bias=False)
#     (o_proj): Linear8bitLt(in_features=4096, out_features=4096, bias=False)
#   )
#   (mlp): LlamaMLP(
#     (gate_proj): Linear8bitLt(in_features=4096, out_features=14336, bias=False)
#     (up_proj): Linear8bitLt(in_features=4096, out_features=14336, bias=False)
#     (down_proj): Linear8bitLt(in_features=14336, out_features=4096, bias=False)
#     (act_fn): SiLU()
#   )
#   (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#   (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
# )
# Layer self_attn.o_proj weight device: cuda:3
# Layer mlp.down_proj weight device: cuda:3
# Steering vector device: cuda:3

# %%
model.save_pretrained("my_models/DeepSeek-R1-Distill-Llama-8B-orthogonalized-10")
tokenizer.save_pretrained("my_models/DeepSeek-R1-Distill-Llama-8B-orthogonalized-10")

# %%
from huggingface_hub import login
login()

model.push_to_hub("dipikakhullar/DeepSeek-R1-Distill-Llama-8B-orthogonalized-10")
tokenizer.push_to_hub("dipikakhullar/DeepSeek-R1-Distill-Llama-8B-orthogonalized-10")

# %%
## apply layer i steering vector to all layers

# %%
# MODEL_NAME = "Qwen/QwQ-32B-Preview"
MODEL_NAME = "deepseek-ai/DeepSeek-R1-Distill-Llama-8B"

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    device_map="cuda:2",
    quantization_config=BitsAndBytesConfig(
        load_in_8bit=True,
    ),
)
model.eval()

# %%
# Apply to all layers
layer_idx = 10

for i, layer in enumerate(model.model.layers):
    device = layer.self_attn.o_proj.weight.device
    print(device)
    steering_vector = steering_vectors[layer_idx].to(device)

    # Convert to float16 before modification
    W_o_proj = layer.self_attn.o_proj.weight.data.to(device = device, dtype=torch.float16)
    W_down_proj = layer.mlp.down_proj.weight.data.to(device = device, dtype=torch.float16)
    
    # Apply orthogonalization
    W_o_proj_orth = get_orthogonalized_matrix(W_o_proj, steering_vector)
    W_down_proj_orth = get_orthogonalized_matrix(W_down_proj, steering_vector)


    # Restore original dtype
    layer.self_attn.o_proj.weight.data = W_o_proj_orth.to(layer.self_attn.o_proj.weight.dtype)
    layer.mlp.down_proj.weight.data = W_down_proj_orth.to(layer.mlp.down_proj.weight.dtype)

    print(f"Orthogonalized layer {i} using layer {steering_vector}'s vector")

# %%
model.save_pretrained("my_models/DeepSeek-R1-Distill-Llama-8B-orthogonalized-all-10")
tokenizer.save_pretrained("my_models/DeepSeek-R1-Distill-Llama-8B-orthogonalized-all-10")

# %%
from huggingface_hub import login
login()

model.push_to_hub("dipikakhullar/DeepSeek-R1-Distill-Llama-8B-orthogonalized-all-10")
tokenizer.push_to_hub("dipikakhullar/DeepSeek-R1-Distill-Llama-8B-orthogonalized-all-10")

# %%
# MODEL_NAME = "Qwen/QwQ-32B-Preview"
MODEL_NAME = "deepseek-ai/DeepSeek-R1-Distill-Llama-8B"

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    device_map="cuda:4",
    quantization_config=BitsAndBytesConfig(
        load_in_8bit=True,
    ),
)
model.eval()
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(128256, 4096)
#     (layers): ModuleList(
#       (0-31): 32 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): Linear8bitLt(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear8bitLt(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear8bitLt(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear8bitLt(in_features=4096, out_features=4096, bias=False)
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear8bitLt(in_features=4096, out_features=14336, bias=False)
#           (up_proj): Linear8bitLt(in_features=4096, out_features=14336, bias=False)
#           (down_proj): Linear8bitLt(in_features=14336, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#         (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#       )
#     )
#     (norm): LlamaRMSNorm((4096,), eps=1e-05)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
# )

# %%
# Apply to all layers
layer_idx = 31

for i, layer in enumerate(model.model.layers):
    device = layer.self_attn.o_proj.weight.device
    print(device)
    steering_vector = steering_vectors[layer_idx].to(device)

    # Convert to float16 before modification
    W_o_proj = layer.self_attn.o_proj.weight.data.to(device = device, dtype=torch.float16)
    W_down_proj = layer.mlp.down_proj.weight.data.to(device = device, dtype=torch.float16)
    
    # Apply orthogonalization
    W_o_proj_orth = get_orthogonalized_matrix(W_o_proj, steering_vector)
    W_down_proj_orth = get_orthogonalized_matrix(W_down_proj, steering_vector)


    # Restore original dtype
    layer.self_attn.o_proj.weight.data = W_o_proj_orth.to(layer.self_attn.o_proj.weight.dtype)
    layer.mlp.down_proj.weight.data = W_down_proj_orth.to(layer.mlp.down_proj.weight.dtype)

    print(f"Orthogonalized layer {i} using layer {steering_vector}'s vector")
# Out:
# cuda:4
# Orthogonalized layer 0 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 1 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 2 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 3 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 4 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 5 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 6 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 7 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 8 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 9 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 10 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 11 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 12 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 13 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 14 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 15 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 16 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 17 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 18 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 19 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 20 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 21 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 22 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 23 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 24 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 25 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 26 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 27 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 28 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 29 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 30 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector
# cuda:4
# Orthogonalized layer 31 using layer tensor([ 0.4543, -0.4604, -0.5591,  ..., -0.3103, -0.5361, -0.5396],
#        device='cuda:4', dtype=torch.float16)'s vector

# %%
model.save_pretrained("my_models/DeepSeek-R1-Distill-Llama-8B-orthogonalized-all-31")
tokenizer.save_pretrained("my_models/DeepSeek-R1-Distill-Llama-8B-orthogonalized-all-31")
# Out:
# ('my_models/DeepSeek-R1-Distill-Llama-8B-orthogonalized-all-31/tokenizer_config.json',
#  'my_models/DeepSeek-R1-Distill-Llama-8B-orthogonalized-all-31/special_tokens_map.json',
#  'my_models/DeepSeek-R1-Distill-Llama-8B-orthogonalized-all-31/tokenizer.json')

# %%
from huggingface_hub import login
login()

model.push_to_hub("dipikakhullar/DeepSeek-R1-Distill-Llama-8B-orthogonalized-all-31")
tokenizer.push_to_hub("dipikakhullar/DeepSeek-R1-Distill-Llama-8B-orthogonalized-all-31")
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# model-00001-of-00002.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.09G [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/5.17k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/dipikakhullar/DeepSeek-R1-Distill-Llama-8B-orthogonalized-all-31/commit/e35f2c57c8a88f3e42dd70fb983208050a1ef224', commit_message='Upload tokenizer', commit_description='', oid='e35f2c57c8a88f3e42dd70fb983208050a1ef224', pr_url=None, repo_url=RepoUrl('https://huggingface.co/dipikakhullar/DeepSeek-R1-Distill-Llama-8B-orthogonalized-all-31', endpoint='https://huggingface.co', repo_type='model', repo_id='dipikakhullar/DeepSeek-R1-Distill-Llama-8B-orthogonalized-all-31'), pr_revision=None, pr_num=None)

# %%
#orthogonalize layer i with steered layer i

# %%
# MODEL_NAME = "Qwen/QwQ-32B-Preview"
MODEL_NAME = "deepseek-ai/DeepSeek-R1-Distill-Llama-8B"

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    device_map="cuda:3",
    quantization_config=BitsAndBytesConfig(
        load_in_8bit=True,
    ),
)
model.eval()

# %%
steering_vectors.keys()

# %%
# Apply to all layers
for i, layer in enumerate(model.model.layers):
    device = layer.self_attn.o_proj.weight.device
    print(device)
    steering_vector = steering_vectors[i].to(device)

    # Convert to float16 before modification
    W_o_proj = layer.self_attn.o_proj.weight.data.to(device = device, dtype=torch.float16)
    W_down_proj = layer.mlp.down_proj.weight.data.to(device = device, dtype=torch.float16)
    
    # Apply orthogonalization
    W_o_proj_orth = get_orthogonalized_matrix(W_o_proj, steering_vector)
    W_down_proj_orth = get_orthogonalized_matrix(W_down_proj, steering_vector)


    # Restore original dtype
    layer.self_attn.o_proj.weight.data = W_o_proj_orth.to(layer.self_attn.o_proj.weight.dtype)
    layer.mlp.down_proj.weight.data = W_down_proj_orth.to(layer.mlp.down_proj.weight.dtype)

    print(f"Orthogonalized layer {i} using layer {steering_vector} steering vector")

# %%
model.save_pretrained("my_models/DeepSeek-R1-Distill-Llama-8B-orthogonalized-all-li")
tokenizer.save_pretrained("my_models/DeepSeek-R1-Distill-Llama-8B-orthogonalized-all-li")

# %%
from huggingface_hub import login
login()

model.push_to_hub("dipikakhullar/DeepSeek-R1-Distill-Llama-8B-orthogonalized-all-li")
tokenizer.push_to_hub("dipikakhullar/DeepSeek-R1-Distill-Llama-8B-orthogonalized-all-li")

# %% [markdown]
# ### Householder transform

# %%
# MODEL_NAME = "Qwen/QwQ-32B-Preview"
MODEL_NAME = "deepseek-ai/DeepSeek-R1-Distill-Llama-8B"

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    device_map="cuda:4",
    quantization_config=BitsAndBytesConfig(
        load_in_8bit=True,
    ),
)
model.eval()
# Out:
# /fsx/ubuntu/miniconda3/envs/task-vector/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/fsx/ubuntu/miniconda3/envs/task-vector/lib/python3.10/site-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(128256, 4096)
#     (layers): ModuleList(
#       (0-31): 32 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): Linear8bitLt(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear8bitLt(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear8bitLt(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear8bitLt(in_features=4096, out_features=4096, bias=False)
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear8bitLt(in_features=4096, out_features=14336, bias=False)
#           (up_proj): Linear8bitLt(in_features=4096, out_features=14336, bias=False)
#           (down_proj): Linear8bitLt(in_features=14336, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#         (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#       )
#     )
#     (norm): LlamaRMSNorm((4096,), eps=1e-05)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
# )

# %%
def get_householder_transform_matrix(W, direction):
    """
    Apply the Householder transformation to the weight matrix W
    using a given direction vector.

    W: torch.Tensor of shape [out_dim, in_dim]
    direction: torch.Tensor of shape [out_dim]
    """
    u = direction / direction.norm()  # Normalize direction vector
    d = u.shape[0]
    I = torch.eye(d, device=W.device, dtype=W.dtype)
    H = I - 2.0 * torch.outer(u, u)  # Householder matrix
    return torch.matmul(H, W)

# %%
# Apply to all layers
layer_idx = 10
steering_vectors = torch.load("steering_vectors_Wait.pt")

for i, layer in enumerate(model.model.layers):
    device = layer.self_attn.o_proj.weight.device
    steering_vector = steering_vectors[layer_idx].to(device)

    # Convert to float16 before modification
    W_o_proj = layer.self_attn.o_proj.weight.data.to(device = device, dtype=torch.float16)
    W_down_proj = layer.mlp.down_proj.weight.data.to(device = device, dtype=torch.float16)
    
    # Apply orthogonalization
    W_o_proj_orth = get_householder_transform_matrix(W_o_proj, steering_vector)
    W_down_proj_orth = get_householder_transform_matrix(W_down_proj, steering_vector)


    # Restore original dtype
    layer.self_attn.o_proj.weight.data = W_o_proj_orth.to(layer.self_attn.o_proj.weight.dtype)
    layer.mlp.down_proj.weight.data = W_down_proj_orth.to(layer.mlp.down_proj.weight.dtype)

    print(f"Householdd layer {i} using layer {steering_vector}'s vector | {device}")
# Out:
# /tmp/ipykernel_2382808/1632714181.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   steering_vectors = torch.load("steering_vectors_Wait.pt")
# Householdd layer 0 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 1 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 2 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 3 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 4 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 5 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 6 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 7 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 8 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 9 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 10 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 11 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 12 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 13 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 14 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 15 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 16 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 17 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 18 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 19 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 20 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 21 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 22 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 23 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 24 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 25 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 26 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 27 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 28 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 29 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 30 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4
# Householdd layer 31 using layer tensor([ 0.0520, -0.0421, -0.0337,  ...,  0.0704,  0.0764,  0.0183],
#        device='cuda:4', dtype=torch.float16)'s vector | cuda:4

# %%
model.save_pretrained("my_models/DeepSeek-R1-Distill-Llama-8B-householder-all-10")
tokenizer.save_pretrained("my_models/DeepSeek-R1-Distill-Llama-8B-householder-all-10")
# Out:
# ('my_models/DeepSeek-R1-Distill-Llama-8B-householder-all-10/tokenizer_config.json',
#  'my_models/DeepSeek-R1-Distill-Llama-8B-householder-all-10/special_tokens_map.json',
#  'my_models/DeepSeek-R1-Distill-Llama-8B-householder-all-10/tokenizer.json')

# %%
from huggingface_hub import login
login(token="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")

model.push_to_hub("dipikakhullar/DeepSeek-R1-Distill-Llama-8B-householder-all-10")
tokenizer.push_to_hub("dipikakhullar/DeepSeek-R1-Distill-Llama-8B-householder-all-10")
# Out:
# No files have been modified since last commit. Skipping to prevent empty commit.
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/dipikakhullar/DeepSeek-R1-Distill-Llama-8B-householder-all-10/commit/76435a14c5f242e9f98e25babcb4f2b97210cb2c', commit_message='Upload tokenizer', commit_description='', oid='76435a14c5f242e9f98e25babcb4f2b97210cb2c', pr_url=None, repo_url=RepoUrl('https://huggingface.co/dipikakhullar/DeepSeek-R1-Distill-Llama-8B-householder-all-10', endpoint='https://huggingface.co', repo_type='model', repo_id='dipikakhullar/DeepSeek-R1-Distill-Llama-8B-householder-all-10'), pr_revision=None, pr_num=None)

# %%
## from transformers import AutoModelForCausalLM, BitsAndBytesConfig

bnb_config = BitsAndBytesConfig(load_in_8bit=True)

baseline_model = AutoModelForCausalLM.from_pretrained(
    "deepseek-ai/DeepSeek-R1-Distill-Llama-8B",
    device_map={"": 1},  # or "cuda:0"
    quantization_config=bnb_config
)

# abl_19_model = AutoModelForCausalLM.from_pretrained(
#     "dipikakhullar/DeepSeek-R1-Distill-Llama-8B-orthogonalized-19",
#     device_map={"": 2},  # or "cuda:1"
#     quantization_config=bnb_config
# )

# abl_all_model = AutoModelForCausalLM.from_pretrained(
#     "dipikakhullar/DeepSeek-R1-Distill-Llama-8B-abliterated-all",
#     device_map={"": 3},  # or "cuda:2"
#     quantization_config=bnb_config
# )



abl_10_model = AutoModelForCausalLM.from_pretrained(
    "dipikakhullar/DeepSeek-R1-Distill-Llama-8B-orthogonalized-10",
    device_map={"": 2},  # or "cuda:1"
    quantization_config=bnb_config
)

abl_all_10_model = AutoModelForCausalLM.from_pretrained(
    "dipikakhullar/DeepSeek-R1-Distill-Llama-8B-orthogonalized-all-10",
    device_map={"": 3},  # or "cuda:2"
    quantization_config=bnb_config
)

abl_all_i_model = AutoModelForCausalLM.from_pretrained(
    "dipikakhullar/DeepSeek-R1-Distill-Llama-8B-orthogonalized-all-i",
    device_map={"": 4},  # or "cuda:2"
    quantization_config=bnb_config
)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/1.32k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/61.2k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.09G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
def compare_layer_weights(model_a, model_b, layer_idx):
    diffs = {}
    layer_a = model_a.model.layers[layer_idx]
    layer_b = model_b.model.layers[layer_idx]

    for name, param_a in layer_a.named_parameters():
        param_b = dict(layer_b.named_parameters())[name]

        # Move to CPU and detach
        param_a_data = param_a.data.detach().cpu()
        param_b_data = param_b.data.detach().cpu()

        # Only compare if it's float or complex (skip int, bool, etc.)
        if not torch.is_floating_point(param_a_data) and not torch.is_complex(param_a_data):
            continue

        diff = torch.norm(param_a_data - param_b_data).item()
        diffs[name] = diff

    return diffs


def compare_layer_weights_verbose(model_a, model_b, layer_idx, key="mlp.down_proj.weight"):
    param_a = dict(model_a.model.layers[layer_idx].named_parameters())[key]
    param_b = dict(model_b.model.layers[layer_idx].named_parameters())[key]

    a_cpu = param_a.detach().float().cpu()
    b_cpu = param_b.detach().float().cpu()
    diff = torch.norm(a_cpu - b_cpu).item()

    print(f"Layer {layer_idx}, Param {key}, Norm diff: {diff}")
    return diff

num_layers = len(baseline_model.model.layers)

# Check down_proj and o_proj diffs per layer
for i in range(num_layers):
    down_diff_19 = compare_layer_weights_verbose(baseline_model, abl_10_model, i, key="mlp.down_proj.weight")
    oproj_diff_19 = compare_layer_weights_verbose(baseline_model, abl_10_model, i, key="self_attn.o_proj.weight")
    
    down_diff_all = compare_layer_weights_verbose(baseline_model, abl_all_i_model, i, key="mlp.down_proj.weight")
    oproj_diff_all = compare_layer_weights_verbose(baseline_model, abl_all_i_model, i, key="self_attn.o_proj.weight")
    
    changed_19 = (down_diff_19 > 1e-5 or oproj_diff_19 > 1e-5)
    changed_all = (down_diff_all > 1e-5 or oproj_diff_all > 1e-5)

    print(f"Layer {i:2d} | Abl_10 changed: {changed_19} | Abl_all changed: {changed_all}")
# Out:
# Layer 0, Param mlp.down_proj.weight, Norm diff: 0.0
# Layer 0, Param self_attn.o_proj.weight, Norm diff: 0.0
# Layer 0, Param mlp.down_proj.weight, Norm diff: 6350.478515625
# Layer 0, Param self_attn.o_proj.weight, Norm diff: 3557.005615234375
# Layer  0 | Abl_10 changed: False | Abl_all changed: True
# Layer 1, Param mlp.down_proj.weight, Norm diff: 0.0
# Layer 1, Param self_attn.o_proj.weight, Norm diff: 0.0
# Layer 1, Param mlp.down_proj.weight, Norm diff: 5984.21875
# Layer 1, Param self_attn.o_proj.weight, Norm diff: 3527.144287109375
# Layer  1 | Abl_10 changed: False | Abl_all changed: True
# Layer 2, Param mlp.down_proj.weight, Norm diff: 0.0
# Layer 2, Param self_attn.o_proj.weight, Norm diff: 0.0
# Layer 2, Param mlp.down_proj.weight, Norm diff: 6012.17236328125
# Layer 2, Param self_attn.o_proj.weight, Norm diff: 3997.685302734375
# Layer  2 | Abl_10 changed: False | Abl_all changed: True
# Layer 3, Param mlp.down_proj.weight, Norm diff: 0.0
# Layer 3, Param self_attn.o_proj.weight, Norm diff: 0.0
# Layer 3, Param mlp.down_proj.weight, Norm diff: 5964.73779296875
# Layer 3, Param self_attn.o_proj.weight, Norm diff: 3769.125732421875
# Layer  3 | Abl_10 changed: False | Abl_all changed: True
# Layer 4, Param mlp.down_proj.weight, Norm diff: 0.0
# Layer 4, Param self_attn.o_proj.weight, Norm diff: 0.0
# Layer 4, Param mlp.down_proj.weight, Norm diff: 5846.25537109375
# Layer 4, Param self_attn.o_proj.weight, Norm diff: 3621.6953125
# Layer  4 | Abl_10 changed: False | Abl_all changed: True
# Layer 5, Param mlp.down_proj.weight, Norm diff: 0.0
# Layer 5, Param self_attn.o_proj.weight, Norm diff: 0.0
# Layer 5, Param mlp.down_proj.weight, Norm diff: 5969.771484375
# Layer 5, Param self_attn.o_proj.weight, Norm diff: 3941.55322265625
# Layer  5 | Abl_10 changed: False | Abl_all changed: True
# Layer 6, Param mlp.down_proj.weight, Norm diff: 0.0
# Layer 6, Param self_attn.o_proj.weight, Norm diff: 0.0
# Layer 6, Param mlp.down_proj.weight, Norm diff: 5943.19091796875
# Layer 6, Param self_attn.o_proj.weight, Norm diff: 3957.68798828125
# Layer  6 | Abl_10 changed: False | Abl_all changed: True
# Layer 7, Param mlp.down_proj.weight, Norm diff: 0.0
# Layer 7, Param self_attn.o_proj.weight, Norm diff: 0.0
# Layer 7, Param mlp.down_proj.weight, Norm diff: 5826.56494140625
# Layer 7, Param self_attn.o_proj.weight, Norm diff: 3624.104248046875
# Layer  7 | Abl_10 changed: False | Abl_all changed: True
# Layer 8, Param mlp.down_proj.weight, Norm diff: 0.0
# Layer 8, Param self_attn.o_proj.weight, Norm diff: 0.0
# Layer 8, Param mlp.down_proj.weight, Norm diff: 5908.77978515625
# Layer 8, Param self_attn.o_proj.weight, Norm diff: 3552.721435546875
# Layer  8 | Abl_10 changed: False | Abl_all changed: True
# Layer 9, Param mlp.down_proj.weight, Norm diff: 0.0
# Layer 9, Param self_attn.o_proj.weight, Norm diff: 0.0
# Layer 9, Param mlp.down_proj.weight, Norm diff: 5884.57373046875
# Layer 9, Param self_attn.o_proj.weight, Norm diff: 3581.6103515625
# Layer  9 | Abl_10 changed: False | Abl_all changed: True
# Layer 10, Param mlp.down_proj.weight, Norm diff: 5897.6357421875
# Layer 10, Param self_attn.o_proj.weight, Norm diff: 4093.043212890625
# Layer 10, Param mlp.down_proj.weight, Norm diff: 5897.6357421875
# Layer 10, Param self_attn.o_proj.weight, Norm diff: 4093.043212890625
# Layer 10 | Abl_10 changed: True | Abl_all changed: True
# Layer 11, Param mlp.down_proj.weight, Norm diff: 0.0
# Layer 11, Param self_attn.o_proj.weight, Norm diff: 0.0
# Layer 11, Param mlp.down_proj.weight, Norm diff: 6012.28271484375
# Layer 11, Param self_attn.o_proj.weight, Norm diff: 3770.15087890625
# Layer 11 | Abl_10 changed: False | Abl_all changed: True
# Layer 12, Param mlp.down_proj.weight, Norm diff: 0.0
# Layer 12, Param self_attn.o_proj.weight, Norm diff: 0.0
# Layer 12, Param mlp.down_proj.weight, Norm diff: 6030.7861328125
# Layer 12, Param self_attn.o_proj.weight, Norm diff: 3837.719482421875
# Layer 12 | Abl_10 changed: False | Abl_all changed: True
# Layer 13, Param mlp.down_proj.weight, Norm diff: 0.0
# Layer 13, Param self_attn.o_proj.weight, Norm diff: 0.0
# Layer 13, Param mlp.down_proj.weight, Norm diff: 6020.1328125
# Layer 13, Param self_attn.o_proj.weight, Norm diff: 3656.047119140625
# Layer 13 | Abl_10 changed: False | Abl_all changed: True
# Layer 14, Param mlp.down_proj.weight, Norm diff: 0.0
# Layer 14, Param self_attn.o_proj.weight, Norm diff: 0.0
# Layer 14, Param mlp.down_proj.weight, Norm diff: 5857.9287109375
# Layer 14, Param self_attn.o_proj.weight, Norm diff: 3493.2919921875
# Layer 14 | Abl_10 changed: False | Abl_all changed: True
# Layer 15, Param mlp.down_proj.weight, Norm diff: 0.0
# Layer 15, Param self_attn.o_proj.weight, Norm diff: 0.0
# Layer 15, Param mlp.down_proj.weight, Norm diff: 5786.59228515625
# Layer 15, Param self_attn.o_proj.weight, Norm diff: 3867.83544921875
# Layer 15 | Abl_10 changed: False | Abl_all changed: True
# Layer 16, Param mlp.down_proj.weight, Norm diff: 0.0
# Layer 16, Param self_attn.o_proj.weight, Norm diff: 0.0
# Layer 16, Param mlp.down_proj.weight, Norm diff: 5812.2783203125
# Layer 16, Param self_attn.o_proj.weight, Norm diff: 3517.225341796875
# Layer 16 | Abl_10 changed: False | Abl_all changed: True
# Layer 17, Param mlp.down_proj.weight, Norm diff: 0.0
# Layer 17, Param self_attn.o_proj.weight, Norm diff: 0.0
# Layer 17, Param mlp.down_proj.weight, Norm diff: 5651.05029296875
# Layer 17, Param self_attn.o_proj.weight, Norm diff: 3426.554931640625
# Layer 17 | Abl_10 changed: False | Abl_all changed: True
# Layer 18, Param mlp.down_proj.weight, Norm diff: 0.0
# Layer 18, Param self_attn.o_proj.weight, Norm diff: 0.0
# Layer 18, Param mlp.down_proj.weight, Norm diff: 5908.60546875
# Layer 18, Param self_attn.o_proj.weight, Norm diff: 3543.944580078125
# Layer 18 | Abl_10 changed: False | Abl_all changed: True
# Layer 19, Param mlp.down_proj.weight, Norm diff: 0.0
# Layer 19, Param self_attn.o_proj.weight, Norm diff: 0.0
# Layer 19, Param mlp.down_proj.weight, Norm diff: 5859.68115234375
# Layer 19, Param self_attn.o_proj.weight, Norm diff: 3789.686279296875
# Layer 19 | Abl_10 changed: False | Abl_all changed: True
# Layer 20, Param mlp.down_proj.weight, Norm diff: 0.0
# Layer 20, Param self_attn.o_proj.weight, Norm diff: 0.0
# Layer 20, Param mlp.down_proj.weight, Norm diff: 5851.8447265625
# Layer 20, Param self_attn.o_proj.weight, Norm diff: 3819.085693359375
# Layer 20 | Abl_10 changed: False | Abl_all changed: True
# Layer 21, Param mlp.down_proj.weight, Norm diff: 0.0
# Layer 21, Param self_attn.o_proj.weight, Norm diff: 0.0
# Layer 21, Param mlp.down_proj.weight, Norm diff: 5698.48486328125
# Layer 21, Param self_attn.o_proj.weight, Norm diff: 3457.588134765625
# Layer 21 | Abl_10 changed: False | Abl_all changed: True
# Layer 22, Param mlp.down_proj.weight, Norm diff: 0.0
# Layer 22, Param self_attn.o_proj.weight, Norm diff: 0.0
# Layer 22, Param mlp.down_proj.weight, Norm diff: 5815.2421875
# Layer 22, Param self_attn.o_proj.weight, Norm diff: 3535.937744140625
# Layer 22 | Abl_10 changed: False | Abl_all changed: True
# Layer 23, Param mlp.down_proj.weight, Norm diff: 0.0
# Layer 23, Param self_attn.o_proj.weight, Norm diff: 0.0
# Layer 23, Param mlp.down_proj.weight, Norm diff: 5834.93994140625
# Layer 23, Param self_attn.o_proj.weight, Norm diff: 3494.597900390625
# Layer 23 | Abl_10 changed: False | Abl_all changed: True
# Layer 24, Param mlp.down_proj.weight, Norm diff: 0.0
# Layer 24, Param self_attn.o_proj.weight, Norm diff: 0.0

# %%
def compare_layer_weights(model_a, model_b, layer_idx):
    diffs = {}
    layer_a = model_a.model.layers[layer_idx]
    layer_b = model_b.model.layers[layer_idx]

    for name, param_a in layer_a.named_parameters():
        param_b = dict(layer_b.named_parameters())[name]

        # Move to CPU and detach
        param_a_data = param_a.data.detach().cpu()
        param_b_data = param_b.data.detach().cpu()

        # Only compare if it's float or complex (skip int, bool, etc.)
        if not torch.is_floating_point(param_a_data) and not torch.is_complex(param_a_data):
            continue

        diff = torch.norm(param_a_data - param_b_data).item()
        diffs[name] = diff

    return diffs


num_layers = len(baseline_model.model.layers)
print("Checking which layers were modified:")

for i in range(num_layers):
    diffs_19 = compare_layer_weights(baseline_model, abl_19_model, i)
    diffs_all = compare_layer_weights(baseline_model, abl_all_model, i)

    changed_19 = any(diff > 1e-5 for diff in diffs_19.values())
    changed_all = any(diff > 1e-5 for diff in diffs_all.values())

    print(f"Layer {i:2d} | Abl_19 changed: {changed_19} | Abl_all changed: {changed_all}")

# %%
def compare_specific_weight(model_a, model_b, layer_idx, param_path):
    layer_a = model_a.model.layers[layer_idx]
    layer_b = model_b.model.layers[layer_idx]

    # Traverse the path manually
    param_a = layer_a
    param_b = layer_b
    for attr in param_path.split('.'):
        param_a = getattr(param_a, attr)
        param_b = getattr(param_b, attr)

    a_cpu = param_a.weight.detach().float().cpu()
    b_cpu = param_b.weight.detach().float().cpu()
    diff = torch.norm(a_cpu - b_cpu).item()

    print(f"Layer {layer_idx}, Param {param_path}.weight diff: {diff:.6f}")
    return diff

compare_specific_weight(baseline_model, abl_19_model, 19, "mlp.down_proj")
compare_specific_weight(baseline_model, abl_19_model, 19, "self_attn.o_proj")

# %%
param_baseline = baseline_model.model.layers[19].mlp.gate_proj.weight.detach().cpu().float()
param_abl = abl_19_model.model.layers[19].mlp.gate_proj.weight.detach().cpu().float()

print("Norm diff:", torch.norm(param_baseline - param_abl).item())

# %%
print("Baseline min/max:", param_baseline.min().item(), param_baseline.max().item())
print("Abliterated min/max:", param_abl.min().item(), param_abl.max().item())
